# %%
from __future__ import print_function, division
import pylab as pl
import pandas as pd
import numpy as np
import scipy.stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from numpy import inf

# %pylab inline
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

import io
import os
import zipfile

#function to download from the url

def getCSV(url, cache_name=None, is_zip=False,**kwargs):
    cache_name = cache_name or os.path.basename(url)
    if is_zip:
            # Get zip buffer
            remotezip = urllib.urlopen(url).read()
            # Open in memory
            with zipfile.ZipFile(io.BytesIO(remotezip)) as z:
                # Read the filename or the first file if there are naming inconsistencies
                read_zip_file = cache_name if cache_name in z.namelist() else z.namelist()[0]
                df = pd.read_csv(z.open(read_zip_file),**kwargs)
    else:
        df = pd.read_csv(urllib.urlopen(url),**kwargs)
    return df
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#downloaded data and uploaded onto compute
df= pd.read_csv("mta_data.csv")

# %%
df.shape
# Out:
# (10267810, 12)

# %%
df.head()
# Out:
#    Unnamed: 0   C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
#
#        TIME     DESC  ENTRIES  \
# 0  03:00:00  REGULAR  5980509
# 1  07:00:00  REGULAR  5980531
# 2  11:00:00  REGULAR  5980613
# 3  15:00:00  REGULAR  5980899
# 4  19:00:00  REGULAR  5981382
#
#    EXITS
# 0                                            2025806
# 1                                            2025818
# 2                                            2025912
# 3                                            2025965
# 4                                            2026001

# %%
# first check for columns with null values
df.isnull().any()
# Out:
# Unnamed: 0                                                              False
# C/A                                                                     False
# UNIT                                                                    False
# SCP                                                                     False
# STATION                                                                 False
# LINENAME                                                                False
# DIVISION                                                                False
# DATE                                                                    False
# TIME                                                                    False
# DESC                                                                    False
# ENTRIES                                                                 False
# EXITS                                                                   False
# dtype: bool

# %%
df = df.dropna()
df.isnull().any()
# Out:
# Unnamed: 0                                                              False
# C/A                                                                     False
# UNIT                                                                    False
# SCP                                                                     False
# STATION                                                                 False
# LINENAME                                                                False
# DIVISION                                                                False
# DATE                                                                    False
# TIME                                                                    False
# DESC                                                                    False
# ENTRIES                                                                 False
# EXITS                                                                   False
# dtype: bool

# %%
#check dtype
df.dtypes
# Out:
# Unnamed: 0                                                               int64
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
# check for unique time values 
df.TIME.unique()
# Out:
# array(['03:00:00', '07:00:00', '11:00:00', ..., '13:12:52', '17:24:52',
#        '07:54:01'], dtype=object)

# %% [markdown]
# As the records are very different, I will strip time to include only hour before sorting them into time interval bins

# %%
df['TIME'] = df['TIME'].str.split(':').str[0]
df['TIME'] = df['TIME'].astype(int)

# %% [markdown]
# Sort times into intervals:
# 1. 0-3
# 2. 4-7
# 3. 8-11
# 4. 12-15
# 5. 16-19
# 6. 20-23

# %%
# sorting into time interval bins
df['TIMEINT'] = pd.cut(df['TIME'], bins=[0,4,8,12,16,20,300], labels=[1,2,3,4,5,6])
df.head()
# Out:
#    Unnamed: 0   C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  12/24/2016
#
#    TIME     DESC  ENTRIES  \
# 0     3  REGULAR  5980509
# 1     7  REGULAR  5980531
# 2    11  REGULAR  5980613
# 3    15  REGULAR  5980899
# 4    19  REGULAR  5981382
#
#    EXITS                                                                 \
# 0                                            2025806
# 1                                            2025818
# 2                                            2025912
# 3                                            2025965
# 4                                            2026001
#
#   TIMEINT
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
# now groupby station and time to aggregate commuter entries per station 
df1= df.groupby(['STATION','DATE','TIMEINT'])['ENTRIES'].sum()
df1
# Out:
# STATION    DATE        TIMEINT
# 1 AV       01/01/2016  1          1407774726
#                        2          1407775796
#                        3          1407776768
#                        4          1407779799
#                        5          1407783611
#                        6          1407786852
#            01/02/2016  1          1407788395
#                        2          1407788714
#                        3          1407790321
#                        4          1407794225
#                        5          1407798688
#                        6          1407802820
#            01/03/2016  1          1407805211
#                        2          1407805739
#                        3          1407807196
#                        4          1407810515
#                        5          1407814293
#                        6          1407817257
#            01/04/2016  1          1407818153
#                        2          1407818810
#                        3          1407824411
#                        4          1407828020
#                        5          1407835582
#                        6          1407839057
#            01/05/2016  1          1407840037
#                        2          1407840684
#                        3          1407846891
#                        4          1407850364
#                        5          1407857897
#                        6          1407861698
#                                      ...
# ZEREGA AV  12/28/2016  1            54254719
#                        2            54255305
#                        3            54255887
#                        4            54256342
#                        5            54256827
#            12/29/2015  1            53464730
#                        2            53465300
#                        3            53465810
#                        4            53466238
#                        5            53466605
#            12/29/2016  1            54256974
#                        2            54257536
#                        3            54258116
#                        4            54258578
#                        5            54259006
#            12/30/2015  1            53466728
#                        2            53467306
#                        3            53467857
#                        4            53468326
#                        5            53468755
#            12/30/2016  1            54259140
#                        2            54259629
#                        3            54260220
#                        4            54260723
#                        5            54261165
#            12/31/2015  1            53468948
#                        2            53469410
#                        3            53469902
#                        4            53470293
#                        5            53470632
# Name: ENTRIES, dtype: int64

# %%
# convert series to dataframe 
df1 = df1.to_frame().reset_index()
df1
# Out:
#           STATION        DATE TIMEINT     ENTRIES
# 0            1 AV  01/01/2016       1  1407774726
# 1            1 AV  01/01/2016       2  1407775796
# 2            1 AV  01/01/2016       3  1407776768
# 3            1 AV  01/01/2016       4  1407779799
# 4            1 AV  01/01/2016       5  1407783611
# 5            1 AV  01/01/2016       6  1407786852
# 6            1 AV  01/02/2016       1  1407788395
# 7            1 AV  01/02/2016       2  1407788714
# 8            1 AV  01/02/2016       3  1407790321
# 9            1 AV  01/02/2016       4  1407794225
# 10           1 AV  01/02/2016       5  1407798688
# 11           1 AV  01/02/2016       6  1407802820
# 12           1 AV  01/03/2016       1  1407805211
# 13           1 AV  01/03/2016       2  1407805739
# 14           1 AV  01/03/2016       3  1407807196
# 15           1 AV  01/03/2016       4  1407810515
# 16           1 AV  01/03/2016       5  1407814293
# 17           1 AV  01/03/2016       6  1407817257
# 18           1 AV  01/04/2016       1  1407818153
# 19           1 AV  01/04/2016       2  1407818810
# 20           1 AV  01/04/2016       3  1407824411
# 21           1 AV  01/04/2016       4  1407828020
# 22           1 AV  01/04/2016       5  1407835582
# 23           1 AV  01/04/2016       6  1407839057
# 24           1 AV  01/05/2016       1  1407840037
# 25           1 AV  01/05/2016       2  1407840684
# 26           1 AV  01/05/2016       3  1407846891
# 27           1 AV  01/05/2016       4  1407850364
# 28           1 AV  01/05/2016       5  1407857897
# 29           1 AV  01/05/2016       6  1407861698
# ...           ...         ...     ...         ...
# 765584  ZEREGA AV  12/28/2016       1    54254719
# 765585  ZEREGA AV  12/28/2016       2    54255305
# 765586  ZEREGA AV  12/28/2016       3    54255887
# 765587  ZEREGA AV  12/28/2016       4    54256342
# 765588  ZEREGA AV  12/28/2016       5    54256827
# 765589  ZEREGA AV  12/29/2015       1    53464730
# 765590  ZEREGA AV  12/29/2015       2    53465300
# 765591  ZEREGA AV  12/29/2015       3    53465810
# 765592  ZEREGA AV  12/29/2015       4    53466238
# 765593  ZEREGA AV  12/29/2015       5    53466605
# 765594  ZEREGA AV  12/29/2016       1    54256974
# 765595  ZEREGA AV  12/29/2016       2    54257536
# 765596  ZEREGA AV  12/29/2016       3    54258116
# 765597  ZEREGA AV  12/29/2016       4    54258578
# 765598  ZEREGA AV  12/29/2016       5    54259006
# 765599  ZEREGA AV  12/30/2015       1    53466728
# 765600  ZEREGA AV  12/30/2015       2    53467306
# 765601  ZEREGA AV  12/30/2015       3    53467857
# 765602  ZEREGA AV  12/30/2015       4    53468326
# 765603  ZEREGA AV  12/30/2015       5    53468755
# 765604  ZEREGA AV  12/30/2016       1    54259140
# 765605  ZEREGA AV  12/30/2016       2    54259629
# 765606  ZEREGA AV  12/30/2016       3    54260220
# 765607  ZEREGA AV  12/30/2016       4    54260723
# 765608  ZEREGA AV  12/30/2016       5    54261165
# 765609  ZEREGA AV  12/31/2015       1    53468948
# 765610  ZEREGA AV  12/31/2015       2    53469410
# 765611  ZEREGA AV  12/31/2015       3    53469902
# 765612  ZEREGA AV  12/31/2015       4    53470293
# 765613  ZEREGA AV  12/31/2015       5    53470632
#
# [765614 rows x 4 columns]

# %%
df1.to_csv('mta_combined.csv',encoding='utf-8')
